# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 35.8 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key= "zgHttWo7G69JCOaDLLVP")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 3986.59it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train", "tennis-ball-detection-6/tennis-ball-detection-6/train")
shutil.move("tennis-ball-detection-6/valid", "tennis-ball-detection-6/tennis-ball-detection-6/valid")
shutil.move("tennis-ball-detection-6/test", "tennis-ball-detection-6/tennis-ball-detection-6/test")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/test'

# %% [markdown]
# ### Run it on Colab on GPU

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone YOLOv5 repo
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17045, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17045 (delta 10), reused 18 (delta 8), pack-reused 17022 (from 1)
# Receiving objects: 100% (17045/17045), 15.66 MiB | 20.46 MiB/s, done.
# Resolving deltas: 100% (11700/11700), done.
# /content/yolov5

# %%
# !yolo task = detect mode = train model = yolov5s.pt data = {dataset.location}/data.yaml epochs = 100 batch = 16 imgsz = 640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
